# %%
from sqlalchemy import create_engine
import dotenv
import os
import pandas as pd
import seaborn as sns

dotenv.load_dotenv(override=True)
username = os.getenv('username')
password = os.getenv('password')
host = os.getenv('host')
dbname = os.getenv('dbname')

import pandas as pd
dbname = "Titanic"
conn_string = f"mysql+pymysql://{username}:{password}@{host}/{dbname}"
db_engine = create_engine(conn_string)
query = """SELECT *
        FROM titanic
        """
titanic = pd.read_sql(query, db_engine)

# %%
titanic.sample()
# Out:
#      PassengerId  PClass                            Name   Sex   Age  SibSp  \
# 110          111       1  Porter, Mr. Walter Chamberlain  male  47.0      0
#
#      Parch  Ticket  Fare Cabin Embarked  Survived EmbarkDate
# 110      0  110465  52.0  C110        S         0  10-4-1912

# %%
titanic.head()
# Out:
#    PassengerId  PClass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket   Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.25              S
# 1  female  38.0      1      0          PC 17599  71.28   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.93              S
# 3  female  35.0      1      0            113803  53.10  C123        S
# 4    male  35.0      0      0            373450   8.05              S
#
#    Survived EmbarkDate
# 0         0  10-4-1912
# 1         1  11-4-1912
# 2         1  10-4-1912
# ...

# %%
#ponti sulla nave
titanic.Parch.value_counts()
# Out:
# Parch
# 0    1002
# 1     170
# 2     113
# 3       8
# 5       6
# 4       6
# 6       2
# 9       2
# Name: count, dtype: int64

# %%
#passengers for each class
titanic.PClass.value_counts()
# Out:
# PClass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
#conteggio barre per passegeri per classe
sns.countplot(data=titanic, x="PClass")
# Out:
# <Axes: xlabel='PClass', ylabel='count'>

# %%
#conteggio passeggerri sopravvisuti 
sns.countplot(data=titanic, x="Survived")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# distribuzione tariffe 
sns.histplot(data=titanic, x="Fare")
# Out:
# C:\Users\HOME\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
# distribuzione dell'età sul titanic 
sns.histplot(data=titanic, x="Age")
# Out:
# C:\Users\HOME\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# distribuzione per età in base alla classe
sns.boxplot(data=titanic, x="PClass", y= "Age")
# Out:
# <Axes: xlabel='PClass', ylabel='Age'>

# %%
# distribuzione per età in base alla classe
sns.violinplot(data=titanic, x="PClass", y= "Age")
# Out:
# <Axes: xlabel='PClass', ylabel='Age'>

# %%
# distribuzione di chi si è salvato e la tariffa del biglietto 
sns.boxplot(data=titanic, x ="Survived", y = "Fare")
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>
