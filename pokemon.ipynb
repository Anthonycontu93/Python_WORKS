# %%
import pandas as pd 
path_dataset2 = "C:/Users/anthony/Desktop/db_esercitazione/dataset/beginner_datasets/"
file2 = "pokemon.csv"
path2 = path_dataset2 + file2

poke = pd.read_csv(path2)

poke.sample(10)


# aggiungi indice che era colonna 
poke.nunique()

poke.columns



#poke.set_index("#", inplace = True)

# filtro leggenda ed grass 
filtro_legend = poke.Legendary
# uso ["Type 1 "] perchè c'è uno spazio 
filtro_grass = poke["Type 1"] == "Grass"

poke.loc[filtro_legend & filtro_grass]

filtro_ice = poke["Type 1"] == "Ice"
filtro_fire = poke["Type 1"] == "Fire"

filtro_complex = filtro_legend & (filtro_ice | filtro_fire)
poke.loc[filtro_complex]


poke.set_index("Name", inplace = True)

filtro_gen = poke.Generation == 1
filtro_attack = poke.Attack > 50
filtro_hp = poke.HP < 60 

filtro_com = filtro_gen & filtro_attack & filtro_hp 

poke.loc[filtro_com]
# Out:
#               #    Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Charmander    4      Fire     NaN    309  39      52       43       60
# Charmeleon    5      Fire     NaN    405  58      64       58       80
# Wartortle     8     Water     NaN    405  59      63       80       65
# Rattata      19    Normal     NaN    253  30      56       35       25
# Raticate     20    Normal     NaN    413  55      81       60       50
# Spearow      21    Normal  Flying    262  40      60       30       31
# Ekans        23    Poison     NaN    288  35      60       44       40
# Pikachu      25  Electric     NaN    320  35      55       40       50
# Sandshrew    27    Ground     NaN    300  50      75       85       20
# Nidoran♂     32    Poison     NaN    273  46      57       40       40
# Paras        46       Bug   Grass    285  35      70       55       45
# Diglett      50    Ground     NaN    265  10      55       25       35
# ...
